# %% [markdown]
# # The best places for placing a supermarket.
# **Applied Data Science Capstone by IBM/Coursera**

# %% [markdown]
# ## Table of contents
# * [Introduction](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction <a name="introduction"></a>
#
# Let's assume that our stakeholder is a supermarket chain. The company operates in a very competitive and volatile environment, so this company has to find new places to expand and leave unpromising locations. This company wants to expand its network in Yekaterinburg city in Russia. But the market in this city is very competitive and we need to do an analysis to find the best places to place supermarkets. Ideally, we need to find crowded places in residential areas without supermarket competitors in the areas.

# %% [markdown]
# ## Data <a name="data"></a>
#
# We need to find places without supermarkets in the area, with public places nearby like a shopping mall or a business center. Residential areas can be distinguished by the presence of schools, kindergartens, and hospitals (social venues) in a neighborhood. All the venues we need can be found using the Foursquare API.
# Yekaterinburg city is divided not into neighborhoods, but huge districts and it's useless to find places for supermarkets by districts.
# I will divide the city by post offices because post offices are evenly distributed throughout the city.
# Also, almost every post office has its postal code.
#
# **Official districts of Yekaterinburg**
# <img src="https://upload.wikimedia.org/wikipedia/commons/3/34/Ekb_all_districts.svg" width="300px">

# %% [markdown]
# ### Getting post offices
# We need to get post office locations and their postal codes. We can find it with the Foursquare API.
# After that, we can see, that Foursquare API returns some locations without postal code. There are also duplicate postal codes. We have to delete such venues.

# %%
# @hidden_cell
import requests as rq
import numpy as np
import pandas as pd
import json
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.cm as cm
import matplotlib.colors as colors
import folium

CLIENT_ID = 'private info'
CLIENT_SECRET = 'private info'
VERSION = '20180604'
RADIUS = 7000
LIMIT = 1000
CATEGORYID = '4bf58dd8d48988d172941735' # post office

lat = '56.8519'
lng = '60.6122'
url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&categoryId={}&radius={}&limit={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        lat, 
        lng, 
        CATEGORYID,
        RADIUS,
        LIMIT)

res = rq.get(url)
post_offices_raw = json.loads(res.text)

# %%
post_offices_raw
# Out:
# {'meta': {'code': 200, 'requestId': '5dcfd3100de0d9001cfc9f06'},
#  'response': {'venues': [{'id': '4f549edae4b0754d59f8a576',
#     'name': 'Почта 620027',
#     'location': {'address': 'ул. Мельковская, 2Б',
#      'lat': 56.85002408076234,
#      'lng': 60.6022097479635,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.85002408076234,
#        'lng': 60.6022097479635}],
#      'distance': 642,
#      'postalCode': '620027',
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['ул. Мельковская, 2Б',
#       '620027, Екатеринбург',
#       'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4cb04504db32f04dea31be4d',
#     'name': 'EMS Почта России',
#     'location': {'address': 'ул. Индустрии, 121',
#      'crossStreet': 'Черноярская ул.',
#      'lat': 56.90633939159328,
#      'lng': 60.61038850707462,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.90633939159328,
#        'lng': 60.61038850707462}],
#      'distance': 6061,
#      'postalCode': '620098',
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['ул. Индустрии, 121 (Черноярская ул.)',
#       '620098, Екатеринбург',
#       'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4cb5492f56fca1cd6a0c4e18',
#     'name': 'Почта России  620089',
#     'location': {'address': 'ул. Онежская, 12',
#      'lat': 56.799070663831635,
#      'lng': 60.64052576641481,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.799070663831635,
#        'lng': 60.64052576641481}],
#      'distance': 6128,
#      'postalCode': '620089',
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['ул. Онежская, 12',
#       '620089, Екатеринбург',
#       'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4df214b8d22d8c5470d7eb04',
#     'name': 'Почта России 620143',
#     'location': {'address': 'ул. Индустрии, 26а',
#      'crossStreet': 'ул. Калинина',
#      'lat': 56.894919965424144,
#      'lng': 60.593024866953414,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.894919965424144,
#        'lng': 60.593024866953414}],
#      'distance': 4928,
#      'postalCode': '620042',
#      'cc': 'RU',
#      'neighborhood': 'Орджоникидзевский',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['ул. Индустрии, 26а (ул. Калинина)',
#       '620042, Екатеринбург',
#       'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4d46a4e2e198721eb1e6d08b',
#     'name': 'Почта России 620086',
#     'location': {'address': 'ул. Пальмиро Тольятти, 15',
#      'lat': 56.821633978244925,
#      'lng': 60.57992491943564,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.821633978244925,
#        'lng': 60.57992491943564}],
#      'distance': 3900,
#      'postalCode': '620102',
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['ул. Пальмиро Тольятти, 15',
#       '620102, Екатеринбург',
#       'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4e6b0e5b18a83989ecbd455a',
#     'name': 'Почта России 620091',
#     'location': {'address': 'ул. Старых Большевиков 75',
#      'crossStreet': 'Войкова',
#      'lat': 56.897599562379085,
#      'lng': 60.62285571939792,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.897599562379085,
#        'lng': 60.62285571939792}],
#      'distance': 5128,
#      'postalCode': '620135',
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['ул. Старых Большевиков 75 (Войкова)',
#       '620135, Екатеринбург',
#       'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4cda7a39fc9737042e74c805',
#     'name': 'Почта России 620073',
#     'location': {'address': 'Тбилисский бул., 3',
#      'lat': 56.79329022267411,
#      'lng': 60.628674163478024,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.79329022267411,
#        'lng': 60.628674163478024}],
#      'distance': 6601,
#      'postalCode': '620073',
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['Тбилисский бул., 3',
#       '620073, Екатеринбург',
#       'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4ded3dc11fc7b24f4416178a',
#     'name': 'Почта России 620092',
#     'location': {'address': 'ул. Сыромолотова, 28а/1',
#      'lat': 56.83489594848963,
#      'lng': 60.68818513677457,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.83489594848963,
#        'lng': 60.68818513677457}],
#      'distance': 4998,
#      'postalCode': '620072',
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['ул. Сыромолотова, 28а/1',
#       '620072, Екатеринбург',
#       'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4e3780a722713b80b9fd5c18',
#     'name': 'Почта России 620102',
#     'location': {'address': 'Белореченская ул., 30',
#      'lat': 56.816212522931025,
#      'lng': 60.562181216088476,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.816212522931025,
#        'lng': 60.562181216088476}],
#      'distance': 5006,
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['Белореченская ул., 30', 'Екатеринбург', 'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4f62a9afe4b09987cfb6b6a5',
#     'name': 'Почта России 620130',
#     'location': {'address': 'Авиационная ул., 69',
#      'lat': 56.80352053483262,
#      'lng': 60.61968650414743,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.80352053483262,
#        'lng': 60.61968650414743}],
#      'distance': 5404,
#      'postalCode': '620130',
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['Авиационная ул., 69',
#       '620130, Екатеринбург',
#       'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4f9a7465e4b020e60e37b36a',
#     'name': 'Отделение почтовой связи 620137',
#     'location': {'lat': 56.8567843807407,
#      'lng': 60.65015288930254,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.8567843807407,
#        'lng': 60.65015288930254}],
#      'distance': 2373,
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['Екатеринбург', 'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4dd3915c7d8b6704c7a7e5fd',
#     'name': 'Почта России 620144',
#     'location': {'address': 'ул. Сурикова, 28',
#      'crossStreet': 'ул. Фрунзе',
#      'lat': 56.812582005497276,
#      'lng': 60.59953458555383,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.812582005497276,
#        'lng': 60.59953458555383}],
#      'distance': 4444,
#      'postalCode': '620144',
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['ул. Сурикова, 28 (ул. Фрунзе)',
#       '620144, Екатеринбург',
#       'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4e97b28f9a52e26642dbdbfc',
#     'name': 'Почта 620078',
#     'location': {'address': 'ул. Мира, 37',
#      'lat': 56.83442549891697,
#      'lng': 60.6545260003029,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.83442549891697,
#        'lng': 60.6545260003029}],
#      'distance': 3228,
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['ул. Мира, 37', 'Екатеринбург', 'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4f9b65a0e4b0e868c1fcac2f',
#     'name': 'Почта России 620149',
#     'location': {'address': 'ул. Академика Бардина, 21а',
#      'lat': 56.80365384367397,
#      'lng': 60.55483661793459,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.80365384367397,
#        'lng': 60.55483661793459}],
#      'distance': 6407,
#      'postalCode': '620149',
#      'cc': 'RU',
#      'neighborhood': 'Ленинский, Свердловская обл',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['ул. Академика Бардина, 21а',
#       '620149, Екатеринбург',
#       'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4da3e65dc6e96ea8618df25d',
#     'name': 'Почта России 620028',
#     'location': {'address': 'Верх-Исетский бул., 25',
#      'lat': 56.83933478515542,
#      'lng': 60.570563040686196,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.83933478515542,
#        'lng': 60.570563040686196}],
#      'distance': 2895,
#      'cc': 'RU',
#      'city': 'город Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['Верх-Исетский бул., 25',
#       'город Екатеринбург',
#       'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4fec1ba8e4b06e7fdf748372',
#     'name': 'Почта, 620076',
#     'location': {'address': 'Гастелло 1',
#      'lat': 56.78526306410043,
#      'lng': 60.64668945933472,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.78526306410043,
#        'lng': 60.64668945933472}],
#      'distance': 7709,
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['Гастелло 1', 'Екатеринбург', 'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4f4f47926b7410b1ce48b8d4',
#     'name': 'Почтовое России 620100 (Почта России 620100)',
#     'location': {'address': 'ул. Восточная, 21',
#      'lat': 56.82717856863616,
#      'lng': 60.63785623557944,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.82717856863616,
#        'lng': 60.63785623557944}],
#      'distance': 3164,
#      'postalCode': '620100',
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['ул. Восточная, 21',
#       '620100, Екатеринбург',
#       'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4efc48dc2c5b0c24ca11906b',
#     'name': 'Почтовое отделение 620142',
#     'location': {'address': 'ул.Фрунзе 20',
#      'lat': 56.81560900559851,
#      'lng': 60.617630223901436,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.81560900559851,
#        'lng': 60.617630223901436}],
#      'distance': 4053,
#      'postalCode': '620142',
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['ул.Фрунзе 20', '620142, Екатеринбург', 'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4dae641e4df0f639f24b6865',
#     'name': 'Почта России 620085',
#     'location': {'address': 'ул. Титова, 14',
#      'lat': 56.7821082719539,
#      'lng': 60.60924763967621,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.7821082719539,
#        'lng': 60.60924763967621}],
#      'distance': 7771,
#      'postalCode': '620085',
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['ул. Титова, 14', '620085, Екатеринбург', 'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4f841b59e4b0748eb71a7fb1',
#     'name': 'Почтовое отделение 620131',
#     'location': {'address': 'Крауля 74',
#      'crossStreet': 'Викулова',
#      'lat': 56.83111107824994,
#      'lng': 60.54535603869647,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.83111107824994,
#        'lng': 60.54535603869647}],
#      'distance': 4681,
#      'postalCode': '620131',
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['Крауля 74 (Викулова)',
#       '620131, Екатеринбург',
#       'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4d7dbf859df3f04d785cb894',
#     'name': 'Почта России 620146',
#     'location': {'address': 'ул. Волгоградская, 47б',
#      'lat': 56.804955616833425,
#      'lng': 60.575867867107576,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.804955616833425,
#        'lng': 60.575867867107576}],
#      'distance': 5675,
#      'postalCode': '620146',
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['ул. Волгоградская, 47б',
#       '620146, Екатеринбург',
#       'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4fa207d7e4b072b68545169e',
#     'name': 'Почта России 620090',
#     'location': {'address': 'ул. Седова, 43',
#      'lat': 56.870267127907006,
#      'lng': 60.52854373217474,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.870267127907006,
#        'lng': 60.52854373217474}],
#      'distance': 5486,
#      'postalCode': '620090',
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['ул. Седова, 43', '620090, Екатеринбург', 'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '5cdcf112d807ee002c9e75f4',
#     'name': 'Сдэк',
#     'location': {'address': 'Сулимова, 23',
#      'lat': 56.861137,
#      'lng': 60.645847,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.861137,
#        'lng': 60.645847}],
#      'distance': 2291,
#      'postalCode': '620137',
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['Сулимова, 23', '620137, Екатеринбург', 'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4e1dbe6c185089860b1e2af8',
#     'name': 'Почта России 620072',
#     'location': {'address': 'Панельная ул., 13',
#      'lat': 56.83170428258644,
#      'lng': 60.6899889452269,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.83170428258644,
#        'lng': 60.6899889452269}],
#      'distance': 5242,
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['Панельная ул., 13', 'Екатеринбург', 'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '52f04d54498e5cf15de03464',
#     'name': 'Uralpress БЦ квартал',
#     'location': {'lat': 56.82136318877789,
#      'lng': 60.650951672347354,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.82136318877789,
#        'lng': 60.650951672347354}],
#      'distance': 4138,
#      'cc': 'RU',
#      'country': 'Россия',
#      'formattedAddress': ['Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '501a55cee4b021ed1ccfde97',
#     'name': 'boxberry',
#     'location': {'address': 'ул. Мамина Сибиряка, 130',
#      'lat': 56.83058218066857,
#      'lng': 60.62124190262443,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.83058218066857,
#        'lng': 60.62124190262443}],
#      'distance': 2436,
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['ул. Мамина Сибиряка, 130',
#       'Екатеринбург',
#       'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '52b04680498e93f3c950f49d',
#     'name': 'почта россии',
#     'location': {'address': 'Бебеля',
#      'lat': 56.87074772126429,
#      'lng': 60.55075563872629,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.87074772126429,
#        'lng': 60.55075563872629}],
#      'distance': 4287,
#      'cc': 'RU',
#      'country': 'Россия',
#      'formattedAddress': ['Бебеля', 'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4cbe77ff021ca1430eb8550c',
#     'name': 'Почта России 620057',
#     'location': {'address': 'ул. Баумана, 58',
#      'lat': 56.89648523724367,
#      'lng': 60.64019361128085,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.89648523724367,
#        'lng': 60.64019361128085}],
#      'distance': 5247,
#      'postalCode': '620057',
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['ул. Баумана, 58',
#       '620057, Екатеринбург',
#       'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4cfa03aac6cca35d5acf8332',
#     'name': 'Екатеринбургский Почтамт (Главпочтамт) / Yekaterinburg General Post Office',
#     'location': {'address': 'просп. Ленина, 39',
#      'crossStreet': 'ул. Пушкина',
#      'lat': 56.83933722807936,
#      'lng': 60.60846297425854,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.83933722807936,
#        'lng': 60.60846297425854}],
#      'distance': 1416,
#      'postalCode': '620000',
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['просп. Ленина, 39 (ул. Пушкина)',
#       '620000, Екатеринбург',
#       'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '5b6bc9dba795bd00398e3aad',
#     'name': 'почта 620026',
#     'location': {'address': 'Декабристов 16/18Б',
#      'lat': 56.824462,
#      'lng': 60.621938,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.824462,
#        'lng': 60.621938}],
#      'distance': 3111,
#      'postalCode': '620000',
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['Декабристов 16/18Б',
#       '620000, Екатеринбург',
#       'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4f684827e4b0d535a5d21a14',
#     'name': 'Почта России',
#     'location': {'address': 'ул. Уральских рабочих, 62',
#      'lat': 56.89952936229622,
#      'lng': 60.5894500647802,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.89952936229622,
#        'lng': 60.5894500647802}],
#      'distance': 5479,
#      'postalCode': '620042',
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['ул. Уральских рабочих, 62',
#       '620042, Екатеринбург',
#       'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '5d1ce85c6d22da002fe88133',
#     'name': 'Почтамат Ozon.Ru',
#     'location': {'lat': 56.886846,
#      'lng': 60.614753,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.886846,
#        'lng': 60.614753}],
#      'distance': 3893,
#      'postalCode': '620000',
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['620000, Екатеринбург', 'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'hierarchy': [],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4e54ca9fae60e3d6b7f17c91',
#     'name': 'Почта России. Отделение 41',
#     'location': {'address': 'Красина 7',
#      'crossStreet': 'Смазчиков',
#      'lat': 56.86064150687646,
#      'lng': 60.623183288647674,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.86064150687646,
#        'lng': 60.623183288647674}],
#      'distance': 1180,
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['Красина 7 (Смазчиков)', 'Екатеринбург', 'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4d84603250913704a9347e5b',
#     'name': 'Почта России 620075',
#     'location': {'lat': 56.83956920549542,
#      'lng': 60.62355043889415,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.83956920549542,
#        'lng': 60.62355043889415}],
#      'distance': 1536,
#      'cc': 'RU',
#      'country': 'Россия',
#      'formattedAddress': ['Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '5a1fceb623472477f5a19607',
#     'name': 'Cdek',
#     'location': {'lat': 56.799408,
#      'lng': 60.58176,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.799408,
#        'lng': 60.58176}],
#      'distance': 6130,
#      'postalCode': '620146',
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['620146, Екатеринбург', 'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '51ecfe5f498e2a044421697f',
#     'name': 'Major Express',
#     'location': {'lat': 56.81554510491154,
#      'lng': 60.62384749338636,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.81554510491154,
#        'lng': 60.62384749338636}],
#      'distance': 4108,
#      'cc': 'RU',
#      'country': 'Россия',
#      'formattedAddress': ['Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '599bf8f49d6a190cf315bf79',
#     'name': 'Boxberry',
#     'location': {'address': 'Кузнецова, 2',
#      'lat': 56.887654,
#      'lng': 60.609526,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.887654,
#        'lng': 60.609526}],
#      'distance': 3983,
#      'postalCode': '620000',
#      'cc': 'RU',
#      'city': 'Yekaterinburg',
#      'state': 'Province of Sverdlovsk',
#      'country': 'Россия',
#      'formattedAddress': ['Кузнецова, 2', '620000, Yekaterinburg', 'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4eba60299a5284afeaa539ab',
#     'name': 'Почтовое отделение 620109',
#     'location': {'address': 'Красноуральская,22',
#      'crossStreet': 'Красноуральская 27',
#      'lat': 56.83319909648101,
#      'lng': 60.55635075655421,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.83319909648101,
#        'lng': 60.55635075655421}],
#      'distance': 3987,
#      'cc': 'RU',
#      'city': 'город Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['Красноуральская,22 (Красноуральская 27)',
#       'город Екатеринбург',
#       'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '580eed8038fa14cf0a22d32c',
#     'name': 'boxberry',
#     'location': {'address': 'улица Радищева 31',
#      'lat': 56.829171,
#      'lng': 60.59158,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.829171,
#        'lng': 60.59158}],
#      'distance': 2824,
#      'postalCode': '620000',
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['улица Радищева 31',
#       '620000, Екатеринбург',
#       'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4d3aa9e3039eb60cf697ed9c',
#     'name': 'Отделение почты',
#     'location': {'address': 'Стрелочников 33к1',
#      'lat': 56.85716202281622,
#      'lng': 60.59249710949322,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.85716202281622,
#        'lng': 60.59249710949322}],
#      'distance': 1334,
#      'cc': 'RU',
#      'city': 'город Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['Стрелочников 33к1',
#       'город Екатеринбург',
#       'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4ef2c7c2e5fad15c7a56663d',
#     'name': 'Почта России 620135',
#     'location': {'address': 'ул. Старых Большевиков, 82, корп. 2',
#      'lat': 56.90189579762868,
#      'lng': 60.62037333356941,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.90189579762868,
#        'lng': 60.62037333356941}],
#      'distance': 5587,
#      'postalCode': '620135',
#      'cc': 'RU',
#      'neighborhood': 'Орджоникидзевский',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['ул. Старых Большевиков, 82, корп. 2',
#       '620135, Екатеринбург',
#       'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '5049ed0ee4b015df2e42c986',
#     'name': 'DHL Express',
#     'location': {'lat': 56.81343519661404,
#      'lng': 60.62876188593856,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.81343519661404,
#        'lng': 60.62876188593856}],
#      'distance': 4399,
#      'cc': 'RU',
#      'country': 'Россия',
#      'formattedAddress': ['Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4f9a2419e4b08fafac2b65ea',
#     'name': 'Почта России',
#     'location': {'address': 'Кузнецова 2',
#      'lat': 56.88769789523711,
#      'lng': 60.61220349170294,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.88769789523711,
#        'lng': 60.61220349170294}],
#      'distance': 3984,
#      'cc': 'RU',
#      'country': 'Россия',
#      'formattedAddress': ['Кузнецова 2', 'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4cb15b6b75ebb60c2fceccad',
#     'name': 'Почта России 620063',
#     'location': {'address': 'ул. 8 марта, 57',
#      'lat': 56.820617571959836,
#      'lng': 60.60613274574279,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.820617571959836,
#        'lng': 60.60613274574279}],
#      'distance': 3501,
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['ул. 8 марта, 57', 'Екатеринбург', 'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '50a5b8c2e4b04d062513c8fd',
#     'name': 'СДЭК',
#     'location': {'lat': 56.84305452296351,
#      'lng': 60.66441193296734,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.84305452296351,
#        'lng': 60.66441193296734}],
#      'distance': 3327,
#      'cc': 'RU',
#      'country': 'Россия',
#      'formattedAddress': ['Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4fe9dc5cbe771cd8f76b8083',
#     'name': 'Почтовое отделение 620050',
#     'location': {'address': 'ул. Техническая, д. 62',
#      'crossStreet': 'Коуровская',
#      'lat': 56.87055646232824,
#      'lng': 60.52284479141235,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.87055646232824,
#        'lng': 60.52284479141235}],
#      'distance': 5820,
#      'postalCode': '620050',
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['ул. Техническая, д. 62 (Коуровская)',
#       '620050, Екатеринбург',
#       'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '57557faa498e75529003f8dc',
#     'name': 'IM-Logistic',
#     'location': {'address': 'Бабушкина 1Б/2',
#      'lat': 56.88137,
#      'lng': 60.627434,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.88137,
#        'lng': 60.627434}],
#      'distance': 3409,
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['Бабушкина 1Б/2', 'Екатеринбург', 'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '54255d75498e501d0eea3b17',
#     'name': 'Почта России',
#     'location': {'address': 'Техническая,62',
#      'lat': 56.87153095532707,
#      'lng': 60.520698572755435,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.87153095532707,
#        'lng': 60.520698572755435}],
#      'distance': 5981,
#      'postalCode': '620050',
#      'cc': 'RU',
#      'country': 'Россия',
#      'formattedAddress': ['Техническая,62', '620050', 'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '4dd3a790fa76c0bf0249fbf3',
#     'name': 'Major Express',
#     'location': {'address': 'Цвиллинга, 4',
#      'lat': 56.817282899428434,
#      'lng': 60.62723173731299,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.817282899428434,
#        'lng': 60.62723173731299}],
#      'distance': 3960,
#      'postalCode': '620142',
#      'cc': 'RU',
#      'city': 'Yekaterinburg',
#      'state': 'Province of Sverdlovsk',
#      'country': 'Россия',
#      'formattedAddress': ['Цвиллинга, 4', '620142, Yekaterinburg', 'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False},
#    {'id': '51d2559f498e0ab45ea79013',
#     'name': 'Почта России 620039',
#     'location': {'address': 'Машиностроителей, 67А',
#      'lat': 56.882844716133775,
#      'lng': 60.568017226227134,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 56.882844716133775,
#        'lng': 60.568017226227134}],
#      'distance': 4369,
#      'postalCode': '620039',
#      'cc': 'RU',
#      'city': 'Екатеринбург',
#      'state': 'Свердловская обл.',
#      'country': 'Россия',
#      'formattedAddress': ['Машиностроителей, 67А',
#       '620039, Екатеринбург',
#       'Россия']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573901074',
#     'hasPerk': False}],
#   'confident': False}}

# %%
post_offices_coords = [(row['location']['address'] if 'address' in row['location'] else np.NaN, row['location']['postalCode'] if 'postalCode' in row['location'] else np.NaN, row['location']['lat'], row['location']['lng']) for row in post_offices_raw['response']['venues']]
post_offices_coords_df = pd.DataFrame(post_offices_coords, columns=['Address', 'Postal code', 'Lat', 'Lng'])

# %%
post_offices_coords_df.shape
# Out:
# (50, 4)

# %%
post_offices_coords_df.dropna(inplace=True)
post_offices_coords_df.shape
# Out:
# (29, 4)

# %%
post_offices_coords_df.drop_duplicates(['Postal code'], inplace=True)
post_offices_coords_df.shape
# Out:
# (22, 4)

# %%
post_offices_map = folium.Map(location=[lat, lng], zoom_start=10)

for p_code, latitude, longitude in zip(post_offices_coords_df['Postal code'], post_offices_coords_df['Lat'], post_offices_coords_df['Lng']):
    label = folium.Popup(str(p_code))
    folium.CircleMarker(
        [latitude, longitude],
        radius=5,
        fill=True,
        popup=label).add_to(post_offices_map)

post_offices_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Getting venues nearby post offices
# The idea is to find places from different categories that can influence the success of the supermarket in a particular place.
# We will find and visualize the number of venues in around post offices in every category:
# * Social venues
#  * Schools
#  * Hospitals
# * Competitor venues
#  * Big Box Stores
#  * Supermarkets
#  * Food & Drink Shops
# * Crowded venues
#  * Business Centers
#  * Offices
#  * Entertainment Centers
#
# As we rely on people coming to a supermarket it must be accessible by walking no more than 15-20 minutes from any place in the area. Assuming the average speed of a person is 6 km/h it will result in a radius of 800 meters.

# %%
# it seems that the radius of 800m is allowable for walking
RADIUS = 800
def get_stat_by_categories(post_offices_df, venue_ids, column_name):
    venues = {}
    for item in post_offices_coords_df.index:
        venues[item] = getNearbyVenuesByCategories(post_offices_df.loc[item]['Lat'],
                                                        post_offices_df.loc[item]['Lng'],
                                                        venue_ids,
                                                        RADIUS)
    post_offices_df[column_name] = post_offices_df.index.to_series().apply(lambda x: len(venues[x]))
    return post_offices_df

def print_map(venues_number_df, column_name):
    post_offices_map = folium.Map(location=[lat, lng], zoom_start=10)

    for level, p_code, latitude, longitude in zip(venues_number_df[column_name], venues_number_df['Postal code'], venues_number_df['Lat'], venues_number_df['Lng']):
        label = folium.Popup(str(p_code) + ' ' + str(level))
        folium.CircleMarker(
            [latitude, longitude],
            fill=True,
            radius=level,
            popup=label).add_to(post_offices_map)
    return post_offices_map

def getNearbyVenuesByCategories(latitude, longitude, categories, radius=500):
    
    # create the API request URL
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&categoryId={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        latitude, 
        longitude, 
        radius, 
        LIMIT,
        ','.join(categories))
    # make the GET request
    results = rq.get(url).json()["response"]['groups'][0]['items']

    # return only relevant information for each nearby venue
    venues_list = [(v['venue']['name'], v['venue']['categories'][0]['name']) for v in results]

    return(venues_list)

# %% [markdown]
# **Social venues**

# %%
post_offices_coords_df = get_stat_by_categories(post_offices_coords_df, ['4bf58dd8d48988d13b941735', '4bf58dd8d48988d196941735'], 'Social venues')
print_map(post_offices_coords_df, 'Social venues')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **Competitor venues**

# %%
post_offices_coords_df = get_stat_by_categories(post_offices_coords_df, ['52f2ab2ebcbc57f1066b8b42', '52f2ab2ebcbc57f1066b8b46', '4bf58dd8d48988d1f9941735'], 'Competitor venues')
print_map(post_offices_coords_df, 'Competitor venues')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **Crowded venues**

# %%
post_offices_coords_df = get_stat_by_categories(post_offices_coords_df, ['56aa371be4b08b9a8d573517', '4bf58dd8d48988d124941735', '4bf58dd8d48988d1e1931735'], 'Crowded venues')
print_map(post_offices_coords_df, 'Crowded venues')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **The summary table of the number of venues in each category by postal office**

# %%
post_offices_coords_df
# Out:
#                        Address Postal code        Lat        Lng  \
# 0          ул. Мельковская, 2Б      620027  56.850024  60.602210
# 1           ул. Индустрии, 121      620098  56.906339  60.610389
# 2             ул. Онежская, 12      620089  56.799071  60.640526
# 3           ул. Индустрии, 26а      620042  56.894920  60.593025
# 4    ул. Пальмиро Тольятти, 15      620102  56.821634  60.579925
# 5    ул. Старых Большевиков 75      620135  56.897600  60.622856
# 6           Тбилисский бул., 3      620073  56.793290  60.628674
# 7      ул. Сыромолотова, 28а/1      620072  56.834896  60.688185
# 9          Авиационная ул., 69      620130  56.803521  60.619687
# 11            ул. Сурикова, 28      620144  56.812582  60.599535
# 13  ул. Академика Бардина, 21а      620149  56.803654  60.554837
# 16           ул. Восточная, 21      620100  56.827179  60.637856
# 17                ул.Фрунзе 20      620142  56.815609  60.617630
# 18              ул. Титова, 14      620085  56.782108  60.609248
# 19                   Крауля 74      620131  56.831111  60.545356
# 20      ул. Волгоградская, 47б      620146  56.804956  60.575868
# 21              ул. Седова, 43      620090  56.870267  60.528544
# 22                Сулимова, 23      620137  56.861137  60.645847
# 27             ул. Баумана, 58      620057  56.896485  60.640194
# 28           просп. Ленина, 39      620000  56.839337  60.608463
# 45      ул. Техническая, д. 62      620050  56.870556  60.522845
# 49       Машиностроителей, 67А      620039  56.882845  60.568017
#
#     Social venues  Competitor venues  Crowded venues
# 0              10                  9              22
# 1               7                 17               6
# 2               5                  9               3
# 3              13                 18               9
# 4               8                 11              24
# 5              11                 18               9
# 6               8                 16               8
# 7               8                 13              11
# 9              10                 18               8
# 11             12                 17              19
# 13             11                 10               7
# 16             16                 15               9
# 17             14                 18              19
# 18              5                  9               5
# 19             11                 22               6
# 20              5                  8               3
# 21              6                  5               8
# 22              7                 11               9
# 27              4                  6               3
# 28             13                 14              30
# 45              7                  4               5
# 49              4                  4               9

# %% [markdown]
# ## Methodology <a name="methodology"></a>
# We collected post office coordinates and their postal codes for dividing the city on neighborhoods because it is impossible to analyze with administrative districts because of their huge sizes. After that, we collected data about venues nearby every post office.
# We used venue types of three relevant for us categories: social venues, competitor venues(other supermarket chains) and crowded venues.
# Now we need to analyze the data. As I think, the best approach is ranking areas by computing a grade for every area.
# The formula for ranking will be:
#
# $r = soc + crw + 2*cmp$
# $r$ - rank
# $crw$ - number of crowded places
# $cmp$ - number of competitor venues
#
# The presence of social and crowded venues is a positive factor, the presence of competitor venues is a huge negative factor, so the multiplier is valid in this case.
# Also, we will try to separate the data using the DBSCAN clustering model, because this model is robust to outliers and can find arbitrarily shaped clusters. I want to try to prove ranking results by clustering results.

# %% [markdown]
# ## Analysis <a name="analysis"></a>
# Let's find out the best places for placing a supermarket. So we need to find the grade for every postal office. Also, we will try to find the difference between areas with the clusterization model.

# %% [markdown]
# **Grading neighborhoods**

# %%
def get_grade(soc_venues_n, comp_venues_n, crowd_venues_n):
    return soc_venues_n + crowd_venues_n - 2*comp_venues_n

graded_post_offices = post_offices_coords_df.copy()
graded_post_offices['Grade'] = graded_post_offices.apply (lambda row: get_grade(row['Social venues'], row['Competitor venues'], row['Crowded venues']), axis=1)

# %%
graded_post_offices.sort_values(by='Grade', ascending=False, inplace=True)
graded_post_offices
# Out:
#                        Address Postal code        Lat        Lng  \
# 28           просп. Ленина, 39      620000  56.839337  60.608463
# 0          ул. Мельковская, 2Б      620027  56.850024  60.602210
# 4    ул. Пальмиро Тольятти, 15      620102  56.821634  60.579925
# 49       Машиностроителей, 67А      620039  56.882845  60.568017
# 45      ул. Техническая, д. 62      620050  56.870556  60.522845
# 21              ул. Седова, 43      620090  56.870267  60.528544
# 13  ул. Академика Бардина, 21а      620149  56.803654  60.554837
# 11            ул. Сурикова, 28      620144  56.812582  60.599535
# 17                ул.Фрунзе 20      620142  56.815609  60.617630
# 16           ул. Восточная, 21      620100  56.827179  60.637856
# 27             ул. Баумана, 58      620057  56.896485  60.640194
# 22                Сулимова, 23      620137  56.861137  60.645847
# 7      ул. Сыромолотова, 28а/1      620072  56.834896  60.688185
# 20      ул. Волгоградская, 47б      620146  56.804956  60.575868
# 18              ул. Титова, 14      620085  56.782108  60.609248
# 2             ул. Онежская, 12      620089  56.799071  60.640526
# 3           ул. Индустрии, 26а      620042  56.894920  60.593025
# 5    ул. Старых Большевиков 75      620135  56.897600  60.622856
# 6           Тбилисский бул., 3      620073  56.793290  60.628674
# 9          Авиационная ул., 69      620130  56.803521  60.619687
# 1           ул. Индустрии, 121      620098  56.906339  60.610389
# 19                   Крауля 74      620131  56.831111  60.545356
#
#     Social venues  Competitor venues  Crowded venues  Grade
# 28             13                 14              30     15
# 0              10                  9              22     14
# 4               8                 11              24     10
# 49              4                  4               9      5
# 45              7                  4               5      4
# 21              6                  5               8      4
# 13             11                 10               7     -2
# 11             12                 17              19     -3
# 17             14                 18              19     -3
# 16             16                 15               9     -5
# 27              4                  6               3     -5
# 22              7                 11               9     -6
# 7               8                 13              11     -7
# 20              5                  8               3     -8
# 18              5                  9               5     -8
# 2               5                  9               3    -10
# 3              13                 18               9    -14
# 5              11                 18               9    -16
# 6               8                 16               8    -16
# 9              10                 18               8    -18
# 1               7                 17               6    -21
# 19             11                 22               6    -27

# %%
print_map(graded_post_offices, 'Grade')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **the DBSCAN model as an alternative approach to prove the result.**
# Use search grid to find the best params.

# %%
df_for_clustering = post_offices_coords_df.loc[:, post_offices_coords_df.columns != 'Address']
best_score = {'eps': 0, 'score': 0}
eps = range(5, 30)
for n in eps:
    kmeans = DBSCAN(eps=n, min_samples=2)
    labels = kmeans.fit(df_for_clustering)
    silhouette_avg = silhouette_score(df_for_clustering, labels.labels_)
    if silhouette_avg > best_score['score']: best_score = {'eps': n, 'score': silhouette_avg}
    print('eps: {}, score: {}'.format(n, silhouette_avg))
print('the best clusters number: {}'.format(best_score['eps']))
# Out:
# eps: 5, score: -0.10256791769146698
# eps: 6, score: -0.03682754190523516
# eps: 7, score: 0.02042905128481953
# eps: 8, score: 0.02042905128481953
# eps: 9, score: 0.25039235024335765
# eps: 10, score: 0.36108044836156883
# eps: 11, score: 0.36108044836156883
# eps: 12, score: 0.28892517676926077
# eps: 13, score: 0.4094089593550984
# eps: 14, score: 0.4094089593550984
# eps: 15, score: 0.4430671932074194
# eps: 16, score: 0.4430671932074194
# eps: 17, score: 0.4810417502408585
# eps: 18, score: 0.5567432733646123
# eps: 19, score: 0.5022568208932578
# eps: 20, score: 0.46278608565523566
# eps: 21, score: 0.46278608565523566
# eps: 22, score: 0.46278608565523566
# eps: 23, score: 0.46278608565523566
# eps: 24, score: 0.46278608565523566
# eps: 25, score: 0.46278608565523566
# eps: 26, score: 0.46278608565523566
# eps: 27, score: 0.46278608565523566
# eps: 28, score: 0.46278608565523566
# eps: 29, score: 0.5525207672042175
# the best clusters number: 18

# %%
clustering = DBSCAN(eps=best_score['eps'], min_samples=2).fit(df_for_clustering)
df_for_clustering.insert(0, 'Cluster Labels', clustering.labels_)

# %%
df_for_clustering.head()
# Out:
#    Cluster Labels Postal code        Lat        Lng  Social venues  \
# 0              -1      620027  56.850024  60.602210             10
# 1               0      620098  56.906339  60.610389              7
# 2               0      620089  56.799071  60.640526              5
# 3               1      620042  56.894920  60.593025             13
# 4               0      620102  56.821634  60.579925              8
#
#    Competitor venues  Crowded venues
# 0                  9              22
# 1                 17               6
# 2                  9               3
# 3                 18               9
# 4                 11              24

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

map_clusters = folium.Map(location=[lat, lng], zoom_start=11)
x = np.arange(len(set(clustering.labels_)))
ys = [i + x + (i*x)**2 for i in range(len(set(clustering.labels_)))]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
markers_colors = []
for lat, lon, poi, cluster in zip(df_for_clustering['Lat'], df_for_clustering['Lng'], df_for_clustering['Postal code'], df_for_clustering['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Results and Discussion <a name="results"></a>
# As we can see, the best results by the ranking are highlighted by DBSCAN as outliers, It means that these results are different from other neighborhoods.
# So the DBSCAN approach almost completely proved the ranking result.
#
# Let's look the best postal codes:
# * Ranking:
#  * 620000
#  * 620027
#  * 620102
# * Clustering:
#  * 620000
#  * 620027
#  * 620012
#
# 620102 and 620012 areas have not such a good grade as 620000 and 620000, so let's exclude these areas.
# So the best places for placing a supermarket are around these post offices:

# %%
result_df = post_offices_coords_df[post_offices_coords_df['Postal code'].isin(['620000', '620027'])]
result_df
# Out:
#                 Address Postal code        Lat        Lng  Social venues  \
# 0   ул. Мельковская, 2Б      620027  56.850024  60.602210             10
# 28    просп. Ленина, 39      620000  56.839337  60.608463             13
#
#     Competitor venues  Crowded venues
# 0                   9              22
# 28                 14              30

# %% [markdown]
# The result is like the truth. These places are residential areas with crowded places in the proximity.
# We considered the vicinity of 800 meters around every coordinate, so stakeholders should find places in a radius 800 meters from the post offices.
# However, the result isn't ideal, because we considered only venues nearby post offices and we could skip some suitable places for supermarkets. Also, we relied on the most popular venue types and didn't use rare types of venues.

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>
# The purpose of this project is to find the best places to place supermarkets in the city with a competitive market.
# We divided the city into neighborhoods by postal offices and found relevant venues with Foursquare API.
# After the analysis, we have found two of the best places for placing a supermarket.
# The final decision on optimal supermarket location will be made by stakeholders based on specific characteristics of neighborhoods and locations in every recommended zone, taking into consideration additional factors like availability of retail space or district welfare level.
